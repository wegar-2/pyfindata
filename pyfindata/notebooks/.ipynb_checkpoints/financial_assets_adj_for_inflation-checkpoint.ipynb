# %%
import os
from pathlib import Path
import sys
sys.path.append(str(Path(os.getcwd()).parent.parent))

# %%
import math

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
from pyfindata.common.ccy import Ccy
from pyfindata.common.ts_config import TSConfig
from pyfindata.extractor.configs import CsvDataFileConfig
from pyfindata.common.freq import Freq
from pyfindata.common.constants import DEFAULT_DATA_PATH
from pyfindata.pipeline.get_merged_stooq_data_pipeline import GetMergedStooqDataPipeline

# %%
import logging

# %%
logger = logging.getLogger("financial-assets-adj-for-inflation")
logger.setLevel(logging.INFO)

# %%
logging.getLogger('matplotlib').setLevel(logging.WARNING)

# %% [markdown]
# ## 1. Load Financial Assets' Prices & Calculate Nominal Price Index Anchored at Dec2019

# %%
ts_configs: list[TSConfig] = [
    TSConfig(ticker="apple", ccy=Ccy.USD, freq=Freq.DAILY),
    TSConfig(ticker="btc", ccy=Ccy.PLN, freq=Freq.DAILY),
    TSConfig(ticker="dax", ccy=Ccy.EUR, freq=Freq.DAILY),
    TSConfig(ticker="eth", ccy=Ccy.USD, freq=Freq.DAILY),
    TSConfig(ticker="eurpln", ccy=Ccy.PLN, freq=Freq.DAILY),
    TSConfig(ticker="nasdaq", ccy=Ccy.USD, freq=Freq.DAILY),
    TSConfig(ticker="nvidia", ccy=Ccy.USD, freq=Freq.DAILY),
    TSConfig(ticker="sp500", ccy=Ccy.USD, freq=Freq.DAILY),
    TSConfig(ticker="tesla", ccy=Ccy.USD, freq=Freq.DAILY),
    TSConfig(ticker="tsmc", ccy=Ccy.USD, freq=Freq.DAILY),
    TSConfig(ticker="usdpln", ccy=Ccy.PLN, freq=Freq.DAILY),
    TSConfig(ticker="xaupln", ccy=Ccy.PLN, freq=Freq.DAILY),
]

# %%
csv_configs: list[CsvDataFileConfig] = [
    CsvDataFileConfig(ts_config=ts_config, filepath=(DEFAULT_DATA_PATH / f"{ts_config.ticker}_{ts_config.ccy.value}.csv"))
    for ts_config in ts_configs
]

# %%
pipeline = GetMergedStooqDataPipeline(csv_configs=csv_configs)
data = pipeline.execute()
# Out:
# 2025-01-11 22:09:07,387 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Extracting Stooq data from CSV files
# 2025-01-11 22:09:07,388 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/apple_usd.csv
# 2025-01-11 22:09:07,405 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/btc_pln.csv
# 2025-01-11 22:09:07,412 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/dax_eur.csv
# 2025-01-11 22:09:07,435 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/eth_usd.csv
# 2025-01-11 22:09:07,451 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/eurpln_pln.csv
# 2025-01-11 22:09:07,463 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/nasdaq_usd.csv
# 2025-01-11 22:09:07,482 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/nvidia_usd.csv
# 2025-01-11 22:09:07,492 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/sp500_usd.csv
# 2025-01-11 22:09:07,522 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/tesla_usd.csv
# 2025-01-11 22:09:07,529 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/tsmc_usd.csv
# 2025-01-11 22:09:07,537 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/usdpln_pln.csv
# 2025-01-11 22:09:07,547 - pyfindata.extractor.stooq_csv_extractor - INFO - Extracting & processing data from file /Users/wegar/github_repos/pyfindata/data/xaupln_pln.csv
# 2025-01-11 22:09:07,555 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting data to currency: Ccy.PLN
# 2025-01-11 22:09:07,555 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Performing conversions from: Ccy.EUR
# 2025-01-11 22:09:07,555 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='dax' ccy=<Ccy.EUR: 'eur'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,559 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Performing conversions from: Ccy.USD
# 2025-01-11 22:09:07,559 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='apple' ccy=<Ccy.USD: 'usd'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,561 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='eth' ccy=<Ccy.USD: 'usd'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,563 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='nasdaq' ccy=<Ccy.USD: 'usd'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,565 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='nvidia' ccy=<Ccy.USD: 'usd'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,567 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='sp500' ccy=<Ccy.USD: 'usd'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,569 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='tesla' ccy=<Ccy.USD: 'usd'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,571 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Converting currency for time series: ticker='tsmc' ccy=<Ccy.USD: 'usd'> freq=<Freq.DAILY: 1>
# 2025-01-11 22:09:07,573 - pyfindata.pipeline.get_merged_stooq_data_pipeline - INFO - Joining the converted data

# %%
data = data.loc["2016-01-01":, :]
data.columns = data.columns.droplevel(level=1)

# %%
assets = ["btc", "xaupln", "dax", "apple", "eth", "nasdaq", "nvidia", "sp500", "tesla", "tsmc"]

# %%
data = data[assets]

# %%
def geometric_mean(numbers):
    product = math.prod(numbers)
    n = len(numbers)
    return product ** (1 / n)

# %%
dec2019 = data.loc["2019-12-01":"2019-12-31", :]

# %%
dec2019_gms = dec2019.groupby(pd.Grouper(freq="m")).agg(geometric_mean)
# Out:
# /var/folders/pn/mflr608s6vdbf4ccdqtxcldw0000gn/T/ipykernel_29969/2060732104.py:1: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dec2019_gms = dec2019.groupby(pd.Grouper(freq="m")).agg(geometric_mean)

# %%
assets_nominal_index = data.div(dec2019_gms.values)

# %%
fig_nai = plt.figure(figsize=(15, 8))
ax_nai = fig_nai.add_subplot(1, 1, 1)
for asset in assets:
    ax_nai.plot(assets_nominal_index[asset], label=asset)
ax_nai.grid()
ax_nai.set_yscale("log")
ax_nai.legend()

# %% [markdown]
# ## 2. Load Data
